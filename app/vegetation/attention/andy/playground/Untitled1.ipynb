# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
file_path = '~/Documents/lfmc/data/best_metrics_all_runs.csv'

# %%
df = pd.read_csv(file_path)
df
# Out:
#                         run_name  epoch  qual_obs_rmse  qual_obs_corrcoef  \
# 0           ex_dropout_0.2_nh_16    350      36.366824           0.589465
# 1           ex_dropout_0.4_nh_16    650      33.285680           0.651336
# 2           ex_dropout_0.2_nh_24    100      34.614980           0.656724
# 3           ex_dropout_0.2_nh_32    350      35.537800           0.618121
# 4           ex_dropout_0.4_nh_24     50      35.343595           0.576820
# ..                           ...    ...            ...                ...
# 79  500m_no_landsat_do_0.8_nh_32   1400      26.548795           0.763669
# 80             500m_do_0.6_nh_32    850      23.855580           0.815617
# 81  500m_no_landsat_do_0.4_nh_32    800      24.306991           0.806493
# 82  500m_no_landsat_do_0.2_nh_32    300      30.830087           0.701628
# 83  500m_no_landsat_do_0.6_nh_32   1450      22.476485           0.837307
#
#     qual_obs_coefdet  qual_site_rmse  qual_site_corrcoef  qual_site_coefdet  \
# ...

# %%
new_df1 = df[df.run_name.str.contains("500m_do_")]
new_df2 = df[df.run_name.str.contains("no_sampling")]
new_df = pd.concat([new_df1, new_df2])
df = new_df
df = df.sort_values('run_name', ascending=False)
df = df[['run_name', 'epoch', 'qual_obs_coefdet']]
# df = df[['epoch', 'run_name', 'qual_obs_rmse', 'qual_obs_corrcoef', 'qual_obs_coefdet']]
df
# Out:
#              run_name  epoch  qual_obs_coefdet
# 78  500m_do_0.8_nh_32   1200          0.658979
# 68  500m_do_0.8_nh_24   1400          0.555265
# 67  500m_do_0.8_nh_16    950          0.627204
# 80  500m_do_0.6_nh_32    850          0.662549
# 66  500m_do_0.6_nh_24   1000          0.546307
# 61  500m_do_0.6_nh_16    700          0.595881
# 74  500m_do_0.4_nh_32    950          0.673705
# 64  500m_do_0.4_nh_24    600          0.635599
# 62  500m_do_0.4_nh_16   1250          0.620541
# 65  500m_do_0.2_nh_32    650          0.663764
# 63  500m_do_0.2_nh_24    750          0.663268
# 60  500m_do_0.2_nh_16    450          0.535806

# %%
6801 - 5780
# Out:
# 1021
