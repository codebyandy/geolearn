# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
file_path = '~/Desktop/best_metrics_all_runs.csv'

# %%
df = pd.read_csv(file_path)

# %%
df = df.drop(range(0, 12)).drop(range(24, 36))
df = df.sort_values('qual_obs_coefdet', ascending=False)
df = df[['run_name', 'qual_obs_rmse', 'qual_obs_corrcoef', 'qual_obs_coefdet']]

# %%
df.iloc[:20]
# Out:
#                                  run_name  qual_obs_rmse  qual_obs_corrcoef  \
# 57  ex_attention_update_dropout_0.6_nh_32      25.910132           0.795087
# 58  ex_attention_update_dropout_0.4_nh_32      26.372780           0.787758
# 56  ex_attention_update_dropout_0.2_nh_32      26.894770           0.781829
# 59  ex_attention_update_dropout_0.8_nh_32      27.786370           0.759955
# 50  ex_attention_update_dropout_0.8_nh_24      28.306379           0.745962
# 19              ex_aqua_dropout_0.2_nh_24      28.453472           0.744940
# 49  ex_attention_update_dropout_0.6_nh_24      28.723781           0.741997
# 16              ex_aqua_dropout_0.6_nh_24      29.296574           0.727717
# 23              ex_aqua_dropout_0.8_nh_32      29.479893           0.729226
# 44   ex_aqua_no_landsat_dropout_0.2_nh_32      29.509967           0.724865
# 18              ex_aqua_dropout_0.8_nh_24      29.517827           0.720459
# ...
