# %%
from hydroDL import kPath

from model import FinalModel
from inference import inference
import data as data

import torch
import numpy as np

import os
import pickle
from matplotlib import pyplot as plt

# %%
from inference import analysis, create_map

# %%
# dict = {"TEST": ["24-03-03_TEST/0/model_450", 450],
#         "TEST1": ["24-03-03_TEST/0/model_450", 450]}

# %%
dict = {"test_new_dataset": ["24-04-01_test_new_dataset/0/final_model", 500],
        "TEST": ["24-03-03_TEST/0/model_450", 450]}

# %%
metrics, fig = analysis(dict)
# Out:
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# ...

# %%
metrics
# Out:
#         RMSE       rsq       Rsq  site-mean RMSE  site-mean rsq  \
# 0  23.620124  0.719358  0.707362       10.496073       0.720835
# 1  28.416358  0.577500  0.576451       11.692755       0.605556
#
#    site-mean Rsq  anomaly RMSE  anomaly rsq  anomaly Rsq
# 0       0.521529     22.213318     0.709640     0.706028
# 1       0.343004     27.170525     0.561883     0.560180

# %%
create_map(dict["TEST"])
# Out:
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# (<Figure size 800x600 with 1 Axes>, <Figure size 800x600 with 2 Axes>)

# %%
nh = 32
rho = 45

# %%
with open(os.path.join(kPath.dirVeg, 'stratified_3_fold.pkl'), 'rb') as f:
    data_tuple = pickle.load(f)

nTup, nxc, lTup = data.get_shapes(data_tuple, rho, "")

model = FinalModel(nTup, nxc, nh, "default")
model_weights = os.path.join(kPath.dirVeg, "runs/24-04-01_test_new_dataset/0/final_model")
model.load_state_dict(torch.load(model_weights))

inference(model, data_tuple, rho, "")
# Out:
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/andyhuynh/anaconda3/envs/pytorch/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# (None,
#  ((24.493742902331537, 0.6704573321202574, 0.659426924200345),
#   (11.10954126509165, 0.6531581900844149, 0.32204070520509764),
#   (22.81420343518003, 0.666532638457811, 0.6658331938692104)))
